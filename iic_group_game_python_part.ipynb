# %% [markdown]
# <a href="https://colab.research.google.com/github/Debashis10/stone-paper-scissors-game-in-python/blob/master/iic_group_game_python_part.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

print("   Lets\'s start the game \"Stone,Paper,Scissors")
round=0
win=0
draw=0
list=["Stone","Paper","Scissors"]
print("0-Stone","1-Paper","2-Scissor","Number of turns is equal to 15")
while round<15:
  cpu=random.randint(0,2)
  print("         TURN-",str(round+1),"       ")
  you=int(input("Please enter your choice: "))
  while you>2 or you<0:
    print("Your input is not valid")
    you=int(input("Please insert again: "))
  print("Your choice: ",list[you])
  print("Computer's choice: ",list[cpu])
  if you==cpu:
    print("DRAW.  sab barabar. koi nahi jita/hara..khusi manao...")
    draw+=1
  else:
    if you==0:
      if cpu==1:
        print(" Ooo Noo...Paper,Stone ki face pakda..Stone ko sas laynay may aai dikat...  YOU LOOSE.")
      if cpu==2:
        print(" Badhai hoo...Stone Scissor pay bola hamla and Scissor buritaraha say ghayal..YOU WIN.")
        win+=1

    elif you==1:
      if cpu==0:
        print("Badhai hoo...Paper,Stone ki face pakda..Stone ko sa laynay may aai dikat...  YOU WIN")
        win+=1
      if cpu==2:
        print("Ooo Noo...Scissor Paper ko kata and Paper ka kisha  khatam....YOU LOOSE")

    elif you==2:
      if cpu==0:
        print("Ooo Noo...Stone Scissor pay bola hamla and Scissor buritaraha say ghayal..YOU LOOSE")
      if cpu==1:
        print("Badhai hoo...Scissor Paper ko kata and Paper ka kisha khatam..YOU WIN")
        win+=1

  round+=1

print("       RESULTS       ")
print("You win: ",str(win))
print("Computer win: ",str(15-win-draw))
print("Number of Drawn: ",str(draw))
# Out:
#    Lets's start the game "Stone,Paper,Scissors
# 0-Stone 1-Paper 2-Scissor Number of turns is equal to 15
#          TURN- 1
# Please enter your choice: 1
# Your choice:  Paper
# Computer's choice:  Scissors
# Ooo Noo...Scissor Paper ko kata and Paper ka kisha  khatam....YOU LOOSE
#          TURN- 2
# Please enter your choice: 1
# Your choice:  Paper
# Computer's choice:  Scissors
# Ooo Noo...Scissor Paper ko kata and Paper ka kisha  khatam....YOU LOOSE
#          TURN- 3
# Please enter your choice: 1
# Your choice:  Paper
# Computer's choice:  Scissors
# Ooo Noo...Scissor Paper ko kata and Paper ka kisha  khatam....YOU LOOSE
#          TURN- 4
# Please enter your choice: 1
# Your choice:  Paper
# Computer's choice:  Scissors
# Ooo Noo...Scissor Paper ko kata and Paper ka kisha  khatam....YOU LOOSE
#          TURN- 5
# Please enter your choice: 1
# Your choice:  Paper
# Computer's choice:  Scissors
# Ooo Noo...Scissor Paper ko kata and Paper ka kisha  khatam....YOU LOOSE
#          TURN- 6
# Please enter your choice: 1
# Your choice:  Paper
# Computer's choice:  Stone
# Badhai hoo...Paper,Stone ki face pakda..Stone ko sa laynay may aai dikat...  YOU WIN
#          TURN- 7
# Please enter your choice: 1
# Your choice:  Paper
# Computer's choice:  Paper
# DRAW.  sab barabar. koi nahi jita/hara..khusi manao...
#          TURN- 8
# Please enter your choice: 1
# Your choice:  Paper
# Computer's choice:  Paper
# DRAW.  sab barabar. koi nahi jita/hara..khusi manao...
#          TURN- 9
# Please enter your choice: 1
# Your choice:  Paper
# Computer's choice:  Stone
# Badhai hoo...Paper,Stone ki face pakda..Stone ko sa laynay may aai dikat...  YOU WIN
#          TURN- 10
# Please enter your choice: 1
# Your choice:  Paper
# Computer's choice:  Stone
# Badhai hoo...Paper,Stone ki face pakda..Stone ko sa laynay may aai dikat...  YOU WIN
#          TURN- 11
# Please enter your choice: 1
# Your choice:  Paper
# Computer's choice:  Scissors
# Ooo Noo...Scissor Paper ko kata and Paper ka kisha  khatam....YOU LOOSE
#          TURN- 12
# Please enter your choice: 1
# Your choice:  Paper
# Computer's choice:  Stone
# Badhai hoo...Paper,Stone ki face pakda..Stone ko sa laynay may aai dikat...  YOU WIN
#          TURN- 13
# Please enter your choice: 1
# Your choice:  Paper
# Computer's choice:  Scissors
# Ooo Noo...Scissor Paper ko kata and Paper ka kisha  khatam....YOU LOOSE
#          TURN- 14
# Please enter your choice: 1
# Your choice:  Paper
# Computer's choice:  Scissors
# Ooo Noo...Scissor Paper ko kata and Paper ka kisha  khatam....YOU LOOSE
#          TURN- 15
# Please enter your choice: 1
# Your choice:  Paper
# Computer's choice:  Scissors
# Ooo Noo...Scissor Paper ko kata and Paper ka kisha  khatam....YOU LOOSE
#        RESULTS
# You win:  4
# Computer win:  9
# Number of Drawn:  2
